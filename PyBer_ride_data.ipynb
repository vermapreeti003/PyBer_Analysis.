# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
y_axis=np.arange(0,20,0.5)

# %%
stdev = statistics.stdev(x_axis)
stdev
# Out:
# 3.605551275463989

# %%
plt.errorbar(x_axis,y_axis, xerr=stdev)
pyber_ride_df.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 plt.errorbar(x_axis,y_axis, xerr=stdev)
#       2 pyber_ride_df.show()
#
# File ~\anaconda\lib\site-packages\matplotlib\pyplot.py:2521, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2515 @_copy_docstring_and_deprecators(Axes.errorbar)
#    2516 def errorbar(
#    2517         x, y, yerr=None, xerr=None, fmt='', ecolor=None,
#    2518         elinewidth=None, capsize=None, barsabove=False, lolims=False,
#    2519         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2520         capthick=None, *, data=None, **kwargs):
# -> 2521     return gca().errorbar(
#    2522         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2523         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#    2524         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2525         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
#    2526         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py:3329, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3327 x, y = np.atleast_1d(x, y)  # Make sure all the args are iterable.
#    3328 if len(x) != len(y):
# -> 3329     raise ValueError("'x' and 'y' must have the same size")
#    3331 if isinstance(errorevery, Integral):
#    3332     errorevery = (0, errorevery)
#
# ValueError: 'x' and 'y' must have the same size
